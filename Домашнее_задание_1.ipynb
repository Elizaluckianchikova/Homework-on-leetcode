# %% [markdown]
# <a href="https://colab.research.google.com/github/Elizaluckianchikova/Homework-on-leetcode/blob/main/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Биостатистика. ДЗ 1

# %% [markdown]
# Загрузка и импорт нужных программ и библиотек

# %%
# !pip install --upgrade --no-cache-dir gdown
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Задание 1 (обязательное)
# Рассчитайте описательную статистику для данных [Cardiovascular Disease](https://www.kaggle.com/datasets/yassinehamdaoui1/cardiovascular-disease).
#
# Для количественных данных:
# - Количество наблюдений
# - Среднее
# - Стандартное отклонение
# - Медиана
# - Квартили (1-й и 3-й)
# - Минимум и максимум
#
# Для качественных данных:
#
# - Количество наблюдений
# - Абсолютные частоты и относительные частоты в процентах.
#
# Результаты сохраните таблицах формата `.xlsx.`
#
# Файл 1 должен содержать статистики для параметров:
# - Потребление алкоголя, литры в год,
# - ИМТ, кг/м2,
# - Употребление табака, кг в год,
# - САД, мм.рт.ст.
#
# Файл 2 должен содержать статистики для параметров:
# - Заболевания сердца в анамнезе семьи (зарегистрированы/не зарегистрированы)
# - Диагноз коронарной недостаточности (имеется/не имеется).
#
# P.S. Если Вы бы хотели посчитать описательные статистики в таком же объеме для какого-то другого открытого датасета — you're welcome.

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Загрузка датасета с моего гугл диска

# %%
# !gdown 14gOspMGf4-mXNTfptzj5F-UACh8X-MWc
# https://drive.google.com/file/d/  14gOspMGf4-mXNTfptzj5F-UACh8X-MWc    /view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=14gOspMGf4-mXNTfptzj5F-UACh8X-MWc
# To: /content/cardiovascular.txt
# 100% 23.5k/23.5k [00:00<00:00, 44.7MB/s]

# %% [markdown]
# Загрузим табличку в объект `DataFrame` библиотеки `pandas`.
#
# Используем функцию `pd.read_csv`. Она преваращает файл CSV (Comma Separated Values) в датафрейм. Наш файл не совсем является форматом csv, значения разделены точкой с запятой `;`. Поэтому в функции надо указать использование разделителя `;` в аргументе `sep` (по дефолту `sep=","`, как в csv).

# %%
df = pd.read_csv('cardiovascular.txt',sep=';')
df
# Out:
#      ind  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0      1  160    12.00   5.73      23.11  Present     49    25.30    97.20
# 1      2  144     0.01   4.41      28.61   Absent     55    28.87     2.06
# 2      3  118     0.08   3.48      32.28  Present     52    29.14     3.81
# 3      4  170     7.50   6.41      38.03  Present     51    31.99    24.26
# 4      5  134    13.60   3.50      27.78  Present     60    25.99    57.34
# ..   ...  ...      ...    ...        ...      ...    ...      ...      ...
# 457  459  214     0.40   5.98      31.72   Absent     64    28.45     0.00
# 458  460  182     4.20   4.41      32.10   Absent     52    28.61    18.72
# 459  461  108     3.00   1.59      15.23   Absent     40    20.09    26.64
# 460  462  118     5.40  11.61      30.79   Absent     64    27.35    23.97
# 461  463  132     0.00   4.82      33.41  Present     62    14.70     0.00
#
#      age  chd
# 0     52    1
# 1     63    1
# 2     46    0
# ...

# %% [markdown]
# Объект `DataFrame` представляет собой таблицу со стояющую из колонок с одинаковым типом данных.  Посмотрим информацию о датафрейме, в том числе типы данных содержащиеся в колонках с помощью метода метода `.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ind        462 non-null    int64
#  1   sbp        462 non-null    int64
#  2   tobacco    462 non-null    float64
#  3   ldl        462 non-null    float64
#  4   adiposity  462 non-null    float64
#  5   famhist    462 non-null    object
#  6   typea      462 non-null    int64
#  7   obesity    462 non-null    float64
#  8   alcohol    462 non-null    float64
#  9   age        462 non-null    int64
#  10  chd        462 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 39.8+ KB

# %% [markdown]
# ## Выбор соответствующих колонок (признаков)

# %% [markdown]
# Аннотация колонок с Kaggle
#
# |Название колонки| Расшифровка|
# |-----|-----|
# |sbp |systolic blood pressure, САД, мм.рт.ст.|
# |tobacco |cumulative tobacco (kg), Употребление табака, кг в год|
# |ldl| low density lipoprotein cholesterol|
# |adiposity| a numeric vector|
# |famhist |Заболевания сердца в анамнезе семьи (зарегистрированы/не зарегистрированы)|
# |typea |type-A behavior|
# |obesity| a numeric vector, ИМТ, кг/м2|
# |alcohol| current alcohol consumption, Потребление алкоголя, литры в год|
# |age| age at onset|
# |chd| Диагноз коронарной недостаточности (имеется/не имеется)|

# %% [markdown]
# Создадим переменные со списоком названий колонок количественных и качественных признаков.

# %%
num_cols = ['alcohol','obesity','tobacco','sbp'] # numerical
cat_cols = ['famhist','chd'] # categorical columns (features)

# %% [markdown]
# Чтобы получить датафрейм только с определенными колонками нужно подать список с названием колонок в квадратные скобки справа от датафрейма так `df[Список_с_названиями_колонок]`.
#
# Используем созданные выше списки для создания таблицы с качественным признаками и таблицы с количественными признаками.

# %%
df_num = df[num_cols] # dataframe with numerical columns (features)
df_cat = df[cat_cols] # dataframe with categorical columns (features)

# %% [markdown]
# ## Расчет описательных статистик

# %% [markdown]
# Метод датафрейма `.describe()` позволяет сразу посчитать основные описательные статистики

# %% [markdown]
# ### Количественные признаки

# %%
df_num_stats = df_num.describe()
df_num_stats
# Out:
#           alcohol     obesity     tobacco         sbp
# count  462.000000  462.000000  462.000000  462.000000
# mean    17.044394   26.044113    3.635649  138.326840
# std     24.481059    4.213680    4.593024   20.496317
# min      0.000000   14.700000    0.000000  101.000000
# 25%      0.510000   22.985000    0.052500  124.000000
# 50%      7.510000   25.805000    2.000000  134.000000
# 75%     23.892500   28.497500    5.500000  148.000000
# max    147.190000   46.580000   31.200000  218.000000

# %% [markdown]
# ### Качественные признаки

# %%
df_cat.describe()
# Out:
#               chd
# count  462.000000
# mean     0.346320
# std      0.476313
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# Вышло не то, что нужно потому что колонка `chd` содеражит цифры и воспринимется как количественный признак. Поэтому для нее считаются описательные статистики как для количественных признаков выше (`.descirbe()` по дефолту считает статистику только для количественных признаков, если есть хотя бы один).
#
# Колонка `chd` не является количественным признаком, потому что по сути значение `0` является `имеется ответ`, а `1` является `не имеется ответ`. Для этих значений не заданы математические операции характерные числам.
#
# Чтобы поменять типы переменных на категориальные применяем метод `.astype('category')`

# %%
df_cat = df_cat.astype('category')
df_cat.describe()
# Out:
#        famhist  chd
# count      462  462
# unique       2    2
# top     Absent    0
# freq       270  302

# %%
df_cat.describe()
# Out:
#        famhist  chd
# count      462  462
# unique       2    2
# top     Absent    0
# freq       270  302

# %% [markdown]
# Посчитались описательные статистики для категориальных данных. Не хватает только строки с относлительной частотой в процентах.

# %%
df_cat_stats = df_cat.describe().T # переворачиваем таблицу, чтобы названия строк стали названиями колонок
freq = df_cat_stats['freq']
count = df_cat_stats['count']
df_cat_stats['rel_freq'] = freq*100/count # создаем новый столбец rel_freq
df_cat_stats = df_cat_stats.T # переворачиваем таблицу обратно

# %% [markdown]
# ## Сохранение полученных таблиц с рассчитанными статистиками

# %%
df_num_stats.to_excel("Cardiov_num_stats.xlsx")
df_cat_stats.to_excel("Cardiova_cat_stats.xlsx")

# %%
df_cat.assign(chd = np.where(df['chd']==1, 'Diagnosed', 'Undiagnosed')) \
      .describe().T \
      .assign(rel_freq = lambda x: x['freq']/x['count']*100).T
# Out:
#             famhist          chd
# count           462          462
# unique            2            2
# top          Absent  Undiagnosed
# freq            270          302
# rel_freq  58.441558    65.367965

# %%
# Функция считающая частоты:
def cat_describe(column):
    count = column.count()
    abs_freq = column.value_counts()
    rel_freq = (abs_freq*100/count)

    count = pd.Series(count, index=['Count'])
    abs_freq = abs_freq.add_suffix('_abs_freq')
    rel_freq = rel_freq.add_suffix('_rel_freq')
    column_stat = pd.concat([count, abs_freq, rel_freq])
    return column_stat

# %%
df_cat.apply(cat_describe,axis=0)
# Out:
#                      famhist         chd
# 0_abs_freq               NaN  302.000000
# 0_rel_freq               NaN   65.367965
# 1_abs_freq               NaN  160.000000
# 1_rel_freq               NaN   34.632035
# Absent_abs_freq   270.000000         NaN
# Absent_rel_freq    58.441558         NaN
# Count             462.000000  462.000000
# Present_abs_freq  192.000000         NaN
# Present_rel_freq   41.558442         NaN

# %%
# df_cat_stats = df_cat.apply(cat_describe,axis=0)
# new_order_index = ['Count'] + df_cat_stats.index.drop('Count').to_list()
# df_cat_stats = df_cat_stats.loc[new_order_index,]
# df_cat_stats
# Out:
#                      famhist         chd
# Count             462.000000  462.000000
# 0_abs_freq               NaN  302.000000
# 0_rel_freq               NaN   65.367965
# 1_abs_freq               NaN  160.000000
# 1_rel_freq               NaN   34.632035
# Absent_abs_freq   270.000000         NaN
# Absent_rel_freq    58.441558         NaN
# Present_abs_freq  192.000000         NaN
# Present_rel_freq   41.558442         NaN

# %% [markdown]
# # Задание 2

# %% [markdown]
# Подготовьте программу, которая будет формировать рандомизационный список для клинического исследования.
#
# Представьте, что вы проводите исследование, в которое нужно включить 64 добровольца. Каждый доброволец (иначе – субъект) должен получить терапию, обозначенную A, или же другую терапию, обозначенную B. Желательно применить блоковую рандомизацию.
#
# Итоговый рандомизационный список должен содержать
#
# - порядок рандомизации (от 1 до 64),
# - код терапии (вектор значений A или B длиной 64),
# - рандомизационный номер (числа от 1 до 64, совпадает с порядком рандомизации; чтобы он отличался от порядка рандомизации, можете добавить к нему какой-нибудь произвольный префикс).
#
# Список нужно выгрузить в файл в формате .csv или .xlsx.

# %%
from numpy.random import choice
import numpy as np

# %%
sample_size = 64
n_batches = 16
groups = ['A','B']

# %%
blocks_ind = np.arange(1,sample_size+1).reshape(n_batches,int(sample_size/n_batches))
blocks_group = np.array([choice(groups, len(i)) for i in blocks_ind])

# %%
df_randomized = pd.DataFrame({'Randomize_order' : blocks_ind.flatten(),
                              'Therapy_code' : blocks_group.flatten()})

df_randomized['Randomize_number'] = 'NUM' + df_randomized['Randomize_order'].astype('str')
df_randomized.head(15)
# Out:
#     Randomize_order Therapy_code Randomize_number
# 0                 1            A             NUM1
# 1                 2            A             NUM2
# 2                 3            A             NUM3
# 3                 4            B             NUM4
# 4                 5            B             NUM5
# 5                 6            A             NUM6
# 6                 7            A             NUM7
# 7                 8            A             NUM8
# 8                 9            A             NUM9
# 9                10            A            NUM10
# 10               11            B            NUM11
# 11               12            A            NUM12
# 12               13            A            NUM13
# 13               14            A            NUM14
# 14               15            A            NUM15

# %%
df_randomized.to_excel('Block_randomized_64.xlsx',index=False)

# %%
# Out:
# 0.0010000001639127731
